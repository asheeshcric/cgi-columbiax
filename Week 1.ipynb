# %% [markdown]
# # Kinematics
#
# 1. Configuration:
#     - e.g: Heights of two elevators describe a configuration in space
#     - e.g: Velocities of two elevators also describe a configuration in terms of velocity
#
# 2. Trajectory:
#     - Change in configuration with respect to time
#     - A curve path traced when the configuration of a system is plotted with explicit time
#
# 3. Velocity:
#     - Important in describing the next state of a configuration space
#
# 4. State:
#     - The complete configuration vector (e.g. containing config space and config velocity) that can describe the current position and the next immediate motion of a system
#     - For convenience, the configuration velocity vector in a state is replaced by a momentum vector (as it is just a product of mass & velocity)
#
# 5. Mass and Inertia (Momentum):
# ![image.png](attachment:image.png)
#
#
# ## Discussion Question
# The configuration space for two elevators is two dimensional. So is the configuration space of a point mass on the plane. It seems therefore that the configuration space of two elevators can be interpreted as the configuration space of a single point mass.
# - Q. What other conditions must exist to establish an equivalence between these two physical systems? (Hint: are there any conditions we must place on the masses?
